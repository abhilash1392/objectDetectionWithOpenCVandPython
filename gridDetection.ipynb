# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flatChess=cv2.imread(r'D:\Coding\OpenCVTutorial\code\objectDetectionWithOpenCVandPython\DATA\flat_chessboard.png')
flatChess=flat

# %%
found,corners=cv2.findChessboardCorners(flatChess,(7,7))

# %%
cv2.drawChessboardCorners(flatChess,(7,7),corners,found)
# Out:
# array([[[158, 206, 255],
#         [158, 206, 255],
#         [158, 206, 255],
#         ...,
#         [ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209]],
#
#        [[158, 206, 255],
#         [158, 206, 255],
#         [158, 206, 255],
#         ...,
#         [ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209]],
#
#        [[158, 206, 255],
#         [158, 206, 255],
#         [158, 206, 255],
#         ...,
#         [ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209]],
#
#        ...,
#
#        [[ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209],
#         ...,
#         [158, 206, 255],
#         [158, 206, 255],
#         [158, 206, 255]],
#
#        [[ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209],
#         ...,
#         [158, 206, 255],
#         [158, 206, 255],
#         [158, 206, 255]],
#
#        [[ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209],
# ...

# %%
plt.imshow(flatChess)

# %%
grid=cv2.imread(r'D:\Coding\OpenCVTutorial\code\objectDetectionWithOpenCVandPython\DATA\dot_grid.png')
plt.imshow(grid)

# %%
found,corners=cv2.findCirclesGrid(grid,(10,10),cv2.CALIB_CB_ASYMMETRIC_GRID)
corners
# Out:
# array([[[ 29.5,  29.5]],
#
#        [[ 89.5,  29.5]],
#
#        [[149.5,  29.5]],
#
#        [[209.5,  29.5]],
#
#        [[269.5,  29.5]],
#
#        [[329.5,  29.5]],
#
#        [[389.5,  29.5]],
#
#        [[449.5,  29.5]],
#
#        [[509.5,  29.5]],
#
#        [[569.5,  29.5]],
#
#        [[ 29.5,  89.5]],
#
#        [[ 89.5,  89.5]],
#
#        [[149.5,  89.5]],
#
#        [[209.5,  89.5]],
#
#        [[269.5,  89.5]],
#
#        [[329.5,  89.5]],
#
#        [[389.5,  89.5]],
#
#        [[449.5,  89.5]],
#
#        [[509.5,  89.5]],
#
#        [[569.5,  89.5]],
#
#        [[ 29.5, 149.5]],
#
#        [[ 89.5, 149.5]],
#
#        [[149.5, 149.5]],
#
#        [[209.5, 149.5]],
#
#        [[269.5, 149.5]],
#
#        [[329.5, 149.5]],
#
#        [[389.5, 149.5]],
#
#        [[449.5, 149.5]],
#
#        [[509.5, 149.5]],
#
#        [[569.5, 149.5]],
#
#        [[ 29.5, 209.5]],
#
#        [[ 89.5, 209.5]],
#
#        [[149.5, 209.5]],
#
#        [[209.5, 209.5]],
#
# ...

# %%
cv2.drawChessboardCorners(grid,(10,10),corners,found)
plt.imshow(grid)
